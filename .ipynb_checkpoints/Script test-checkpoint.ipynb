# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

class data_class:

    def __init__(self):
        self.data = None
    
    def read_data(self):
        file_path = input("Please Enter File Path : ")
        if(file_path[-1] == "n"):
            self.data = pd.read_json(file_path)
        elif(file_path[-1] == "v"):
            self.data = pd.read_csv(file_path)
        elif(file_path[-1] == "x"):
            self.data = pd.read_xlsx(file_path)
        else:
            print("This File Isn't Valid")
    
    def data_summary(self,data):
        # give general info
        # give me a special column
        # handle if the chosen column is categorical
        print("1.Information about all the columns and it situations and how many rows :-\n")
        print(self.data.info())
        print("______________________________________________\n")

        #ask the user if want information about a particular column :acoording to the replay
        info_about_column = input("Do you want some analysis about a particular column (N) if you don't want :")
        behave = False
        if(info_about_column == "N"):
            print("Thank you for Using my system!")
        else:
            #here we check if the user entered a right colum name or not
            for i in self.data.columns:
                if(i == info_about_column):
                    #the column is exit
                    behave = True
                    break
            if(behave):#This line edited according to the replay :
                if(self.data[info_about_column].dtype == "int64" or self.data[info_about_column].dtype == 'float64'):
                    print("Here we can know what is the values that's exist in this column and how many times it reapeat\n")
                    print("if it's an integer column it'll show the minimum value and the maximum and the ranges of the values from 25% 50% 75% \n")
                    #general information about the whole table columns and more
                    print(self.data[info_about_column].describe())
                    print("______________________________________________\n")
                    #the most repeated value in one of the columns
                    print("And now in this column the most repeated value is :")
                    self.data[info_about_column].mode()
                    print("______________________________________________\n")
                    #the mean for one of the columns using pandas
                    print("The mean of the target column :- \n")
                    #print(self.data[info_about_column].mean())
                    print("______________________________________________\n")
                    #the mean for one of the columns using NumPy
                    print(np.mean(self.data[info_about_column]))
                    print("______________________________________________\n")
                    # to know the greatest value in the column using numpy
                    print("The Highest value of the target column :- \n")
                    print(np.max(self.data[info_about_column]))
                    print("______________________________________________\n")
                    # to know the smallest value in the column using numpy
                    print("The Smallest of the target column :- \n")
                    print(np.min(self.data[info_about_column]))

                    #this part added according to the replay
                    _, axs = plt.subplots(2,2)
                    axs[0,0].plot(self.data[info_about_column])
                    axs[0,1].plot(self.data[info_about_column].value_counts())
                    axs[1,0].hist(self.data[info_about_column])
                    axs[1, 1].hist(self.data[info_about_column].value_counts())
                    plt.tight_layout()
                    plt.show()

                else:
                    print("______________________________________________\n")
                    #to know how much is the values and how much it repeated
                    print("That's  not a numerical data \n")
                    print("The values that's exist in this column and the repeats:- \n")
                    print(self.data[info_about_column].value_counts())
                    #added according to the replay
                    plt.plot(self.data[info_about_column].value_counts())
                    plt.show()
                    print("______________________________________________\n")
            else:
                print("sorry there's no column at this name")
                
    def clear_missing(self,data):
        # check the entered data
        print("First The Empty Rows is \n")
        empty_rows = data[data.isnull().any(axis=1)]
        ans = input("Do you wanna delete or fill the empty cells (D/F): ")
        if(ans == "D"):
            data = data.dropna()
            return data
        if(ans == "F"):
            fill = input("you wanna fill it with : ")
            data = data.fillna(fill)
            return data
        else:
            print("Invalid input")
    
    def  categorys(self,data,categ):
        data.groupby(categ).describe()
    
    def encode_categorical_data(self,data):
        return pd.get_dummies(data)

# %%
data = data_class()

# %%
data.read_data()
# Out:
# Please Enter File Path :  file.csv

# %%
data.data
# data came successfuly
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2021                     Level 1                99999
# 1      2021                     Level 1                99999
# 2      2021                     Level 1                99999
# 3      2021                     Level 1                99999
# 4      2021                     Level 1                99999
# ...     ...                         ...                  ...
# 41710  2021                     Level 3                 ZZ11
# 41711  2021                     Level 3                 ZZ11
# 41712  2021                     Level 3                 ZZ11
# 41713  2013                     Level 3                 ZZ11
# 41714  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# 2                  All industries  Dollars (millions)           H05
# 3                  All industries  Dollars (millions)           H07
# 4                  All industries  Dollars (millions)           H08
# ...                           ...                 ...           ...
# 41710  Food product manufacturing          Percentage           H37
# 41711  Food product manufacturing          Percentage           H38
# 41712  Food product manufacturing          Percentage           H39
# 41713  Food product manufacturing          Percentage           H40
# 41714  Food product manufacturing          Percentage           H41
#
#                                          Variable_name      Variable_category  \
# 0                                         Total income  Financial performance
# 1      Sales, government funding, grants and subsidies  Financial performance
# 2                    Interest, dividends and donations  Financial performance
# 3                                 Non-operating income  Financial performance
# 4                                    Total expenditure  Financial performance
# ...                                                ...                    ...
# 41710                                      Quick ratio       Financial ratios
# 41711              Margin on sales of goods for resale       Financial ratios
# 41712                                 Return on equity       Financial ratios
# 41713                           Return on total assets       Financial ratios
# 41714                            Liabilities structure       Financial ratios
#
#          Value                             Industry_code_ANZSIC06
# 0      757,504  ANZSIC06 divisions A-S (excluding classes K633...
# 1      674,890  ANZSIC06 divisions A-S (excluding classes K633...
# 2       49,593  ANZSIC06 divisions A-S (excluding classes K633...
# 3       33,020  ANZSIC06 divisions A-S (excluding classes K633...
# 4      654,404  ANZSIC06 divisions A-S (excluding classes K633...
# ...        ...                                                ...
# 41710       52  ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 41711       40  ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 41712       12  ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 41713        5  ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 41714       46  ANZSIC06 groups C111, C112, C113, C114, C115, ...
#
# [41715 rows x 10 columns]

# %%
data.data_summary(data)
# Out:
# 1.Information about all the columns and it situations and how many rows :-
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41715 entries, 0 to 41714
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Year                         41715 non-null  int64
#  1   Industry_aggregation_NZSIOC  41715 non-null  object
#  2   Industry_code_NZSIOC         41715 non-null  object
#  3   Industry_name_NZSIOC         41715 non-null  object
#  4   Units                        41715 non-null  object
#  5   Variable_code                41715 non-null  object
#  6   Variable_name                41715 non-null  object
#  7   Variable_category            41715 non-null  object
#  8   Value                        41715 non-null  object
#  9   Industry_code_ANZSIC06       41715 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 3.2+ MB
# None
# ______________________________________________
# Do you want some analysis about a particular column (N) if you don't want : Year
# Here we can know what is the values that's exist in this column and how many times it reapeat
#
# if it's an integer column it'll show the minimum value and the maximum and the ranges of the values from 25% 50% 75%
#
# count    41715.000000
# mean      2017.004219
# std          2.582016
# min       2013.000000
# 25%       2015.000000
# 50%       2017.000000
# 75%       2019.000000
# max       2021.000000
# Name: Year, dtype: float64
# ______________________________________________
#
# And now in this column the most repeated value is :
# ______________________________________________
#
# The mean of the target column :-
#
# ______________________________________________
#
# 2017.0042191058371
# ______________________________________________
#
# The Highest value of the target column :-
#
# 2021
# ______________________________________________
#
# The Smallest of the target column :-
#
# 2013
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 data.data_summary(data)
#
# Cell In[60], line 72, in data_class.data_summary(self, data)
#      70 axs[0,0].plot(self.data[info_about_column])
#      71 axs[0,1].plot(self.data[info_about_column].value_counts())
# ---> 72 axs[1,0].self.data[info_about_column].hist()
#      73 axs[1, 1].hist(self.data[info_about_column].value_counts())
#      74 plt.tight_layout()
#
# AttributeError: 'Axes' object has no attribute 'self'

# %%
data.data_summary(data) # this is a numerical column

# %%
data.data_summary(data) # not numerical data

# %%
#this is for creating a random empty value in the table
data.data["Empty"] = np.random.randint(0,2,len(data.data))
data.data["Empty"] = np.where(data.data["Empty"] == 0,None,1)

# %%
data.data["Empty"].value_counts()
# Out:
# Empty
# 1    20679
# Name: count, dtype: int64

# %%
#Here's I succeeded to fill the none places with 1
data.clear_missing(data.data)
# Out:
# First The Empty Rows is
# Do you wanna delete or fill the empty cells (D/F):  D
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2021                     Level 1                99999
# 2      2021                     Level 1                99999
# 6      2021                     Level 1                99999
# 8      2021                     Level 1                99999
# 12     2021                     Level 1                99999
# ...     ...                         ...                  ...
# 41702  2021                     Level 3                 ZZ11
# 41708  2021                     Level 3                 ZZ11
# 41709  2021                     Level 3                 ZZ11
# 41710  2021                     Level 3                 ZZ11
# 41713  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 2                  All industries  Dollars (millions)           H05
# 6                  All industries  Dollars (millions)           H10
# 8                  All industries  Dollars (millions)           H12
# 12                 All industries  Dollars (millions)           H20
# ...                           ...                 ...           ...
# 41702  Food product manufacturing  Dollars (millions)           H29
# 41708  Food product manufacturing             Dollars           H35
# 41709  Food product manufacturing          Percentage           H36
# 41710  Food product manufacturing          Percentage           H37
# 41713  Food product manufacturing          Percentage           H40
#
#                            Variable_name      Variable_category    Value  \
# 0                           Total income  Financial performance  757,504
# 2      Interest, dividends and donations  Financial performance   49,593
# 6                         Indirect taxes  Financial performance    6,991
# 8                Salaries and wages paid  Financial performance  123,620
# 12                Non-operating expenses  Financial performance   14,806
# ...                                  ...                    ...      ...
# 41702                       Other assets     Financial position    5,434
# 41708         Surplus per employee count       Financial ratios   17,700
# 41709                      Current ratio       Financial ratios       91
# 41710                        Quick ratio       Financial ratios       52
# 41713             Return on total assets       Financial ratios        5
#
#                                   Industry_code_ANZSIC06 Empty
# 0      ANZSIC06 divisions A-S (excluding classes K633...     1
# 2      ANZSIC06 divisions A-S (excluding classes K633...     1
# 6      ANZSIC06 divisions A-S (excluding classes K633...     1
# 8      ANZSIC06 divisions A-S (excluding classes K633...     1
# 12     ANZSIC06 divisions A-S (excluding classes K633...     1
# ...                                                  ...   ...
# 41702  ANZSIC06 groups C111, C112, C113, C114, C115, ...     1
# 41708  ANZSIC06 groups C111, C112, C113, C114, C115, ...     1
# 41709  ANZSIC06 groups C111, C112, C113, C114, C115, ...     1
# 41710  ANZSIC06 groups C111, C112, C113, C114, C115, ...     1
# 41713  ANZSIC06 groups C111, C112, C113, C114, C115, ...     1
#
# [20679 rows x 11 columns]

# %%
#Here Succeeded to delete all the empty rows
data.clear_missing(data.data)
# Out:
# First The Empty Rows is
# Do you wanna delete or fill the empty cells (D/F):  F
# you wanna fill it with :  I'm fill
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2021                     Level 1                99999
# 1      2021                     Level 1                99999
# 2      2021                     Level 1                99999
# 3      2021                     Level 1                99999
# 4      2021                     Level 1                99999
# ...     ...                         ...                  ...
# 41710  2021                     Level 3                 ZZ11
# 41711  2021                     Level 3                 ZZ11
# 41712  2021                     Level 3                 ZZ11
# 41713  2013                     Level 3                 ZZ11
# 41714  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# 2                  All industries  Dollars (millions)           H05
# 3                  All industries  Dollars (millions)           H07
# 4                  All industries  Dollars (millions)           H08
# ...                           ...                 ...           ...
# 41710  Food product manufacturing          Percentage           H37
# 41711  Food product manufacturing          Percentage           H38
# 41712  Food product manufacturing          Percentage           H39
# 41713  Food product manufacturing          Percentage           H40
# 41714  Food product manufacturing          Percentage           H41
#
#                                          Variable_name      Variable_category  \
# 0                                         Total income  Financial performance
# 1      Sales, government funding, grants and subsidies  Financial performance
# 2                    Interest, dividends and donations  Financial performance
# 3                                 Non-operating income  Financial performance
# 4                                    Total expenditure  Financial performance
# ...                                                ...                    ...
# 41710                                      Quick ratio       Financial ratios
# 41711              Margin on sales of goods for resale       Financial ratios
# 41712                                 Return on equity       Financial ratios
# 41713                           Return on total assets       Financial ratios
# 41714                            Liabilities structure       Financial ratios
#
#          Value                             Industry_code_ANZSIC06     Empty
# 0      757,504  ANZSIC06 divisions A-S (excluding classes K633...         1
# 1      674,890  ANZSIC06 divisions A-S (excluding classes K633...  I'm fill
# 2       49,593  ANZSIC06 divisions A-S (excluding classes K633...         1
# 3       33,020  ANZSIC06 divisions A-S (excluding classes K633...  I'm fill
# 4      654,404  ANZSIC06 divisions A-S (excluding classes K633...  I'm fill
# ...        ...                                                ...       ...
# 41710       52  ANZSIC06 groups C111, C112, C113, C114, C115, ...         1
# 41711       40  ANZSIC06 groups C111, C112, C113, C114, C115, ...  I'm fill
# 41712       12  ANZSIC06 groups C111, C112, C113, C114, C115, ...  I'm fill
# 41713        5  ANZSIC06 groups C111, C112, C113, C114, C115, ...         1
# 41714       46  ANZSIC06 groups C111, C112, C113, C114, C115, ...  I'm fill
#
# [41715 rows x 11 columns]

# %%
#finally the encoding
data.encode_categorical_data(data.data)
# Out:
#        Year  Industry_aggregation_NZSIOC_Level 1  \
# 0      2021                                 True
# 1      2021                                 True
# 2      2021                                 True
# 3      2021                                 True
# 4      2021                                 True
# ...     ...                                  ...
# 41710  2013                                False
# 41711  2013                                False
# 41712  2013                                False
# 41713  2013                                False
# 41714  2013                                False
#
#        Industry_aggregation_NZSIOC_Level 3  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
# ...                                    ...
# 41710                                 True
# 41711                                 True
# 41712                                 True
# 41713                                 True
# 41714                                 True
#
#        Industry_aggregation_NZSIOC_Level 4  Industry_code_NZSIOC_99999  \
# 0                                    False                        True
# 1                                    False                        True
# 2                                    False                        True
# 3                                    False                        True
# 4                                    False                        True
# ...                                    ...                         ...
# 41710                                False                       False
# 41711                                False                       False
# 41712                                False                       False
# 41713                                False                       False
# 41714                                False                       False
#
#        Industry_code_NZSIOC_AA  Industry_code_NZSIOC_AA11  \
# 0                        False                      False
# 1                        False                      False
# 2                        False                      False
# 3                        False                      False
# 4                        False                      False
# ...                        ...                        ...
# 41710                    False                      False
# 41711                    False                      False
# 41712                    False                      False
# 41713                    False                      False
# 41714                    False                      False
#
#        Industry_code_NZSIOC_AA111  Industry_code_NZSIOC_AA12  \
# 0                           False                      False
# 1                           False                      False
# 2                           False                      False
# 3                           False                      False
# 4                           False                      False
# ...                           ...                        ...
# 41710                       False                      False
# 41711                       False                      False
# 41712                       False                      False
# 41713                       False                      False
# 41714                       False                      False
#
#        Industry_code_NZSIOC_AA121  ...  \
# 0                           False  ...
# 1                           False  ...
# 2                           False  ...
# 3                           False  ...
# 4                           False  ...
# ...                           ...  ...
# 41710                       False  ...
# 41711                       False  ...
# 41712                       False  ...
# 41713                       False  ...
# 41714                       False  ...
#
#        Industry_code_ANZSIC06_ANZSIC06 groups N731 and N732  \
# 0                                                  False
# 1                                                  False
# 2                                                  False
# 3                                                  False
# 4                                                  False
# ...                                                  ...
# 41710                                              False
# 41711                                              False
# 41712                                              False
# 41713                                              False
# 41714                                              False
#
#        Industry_code_ANZSIC06_ANZSIC06 groups O771 and O772 (excluding class O7711)  \
# 0                                                  False
# 1                                                  False
# 2                                                  False
# 3                                                  False
# 4                                                  False
# ...                                                  ...
# 41710                                              False
# 41711                                              False
# 41712                                              False
# 41713                                              False
# 41714                                              False
#
#        Industry_code_ANZSIC06_ANZSIC06 groups P821 and P822  \
# 0                                                  False
# 1                                                  False
# 2                                                  False
# 3                                                  False
# 4                                                  False
# ...                                                  ...
# 41710                                              False
# 41711                                              False
# 41712                                              False
# 41713                                              False
# 41714                                              False
#
#        Industry_code_ANZSIC06_ANZSIC06 groups Q851, Q852, Q853, and Q859  \
# 0                                                  False
# 1                                                  False
# 2                                                  False
# 3                                                  False
# 4                                                  False
# ...                                                  ...
# 41710                                              False
# 41711                                              False
# 41712                                              False
# 41713                                              False
# 41714                                              False
#
#        Industry_code_ANZSIC06_ANZSIC06 groups Q860, Q871, and Q879  \
# 0                                                  False
# 1                                                  False
# 2                                                  False
# 3                                                  False
# 4                                                  False
# ...                                                  ...
# 41710                                              False
# 41711                                              False
# 41712                                              False
# 41713                                              False
# 41714                                              False
#
#        Industry_code_ANZSIC06_ANZSIC06 groups R891, R892, and R900  \
# 0                                                  False
# 1                                                  False
# 2                                                  False
# 3                                                  False
# 4                                                  False
# ...                                                  ...
# 41710                                              False
# 41711                                              False
# 41712                                              False
# 41713                                              False
# 41714                                              False
#
#        Industry_code_ANZSIC06_ANZSIC06 groups R911, R912, and R913  \
# 0                                                  False
# 1                                                  False
# 2                                                  False
# 3                                                  False
# 4                                                  False
# ...                                                  ...
# 41710                                              False
# 41711                                              False
# 41712                                              False
# 41713                                              False
# 41714                                              False
#
#        Industry_code_ANZSIC06_ANZSIC06 groups S941, S942, and S949  \
# 0                                                  False
# 1                                                  False
# 2                                                  False
# 3                                                  False
# 4                                                  False
# ...                                                  ...
# 41710                                              False
# 41711                                              False
# 41712                                              False
# 41713                                              False
# 41714                                              False
#
#        Industry_code_ANZSIC06_ANZSIC06 groups S951, S952, and S953  Empty_1
# 0                                                  False               True
# 1                                                  False               True
# 2                                                  False               True
# 3                                                  False               True
# 4                                                  False               True
# ...                                                  ...                ...
# 41710                                              False              False
# 41711                                              False               True
# 41712                                              False              False
# 41713                                              False               True
# 41714                                              False               True
#
# [41715 rows x 10554 columns]
